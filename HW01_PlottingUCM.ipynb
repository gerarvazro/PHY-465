# %% [markdown]
# # Homework 01:  Plotting Uniform Accelerated Motion.
# ## For the following physics problem, make three separate graphs: time vs position, time vs velocity, and time vs acceleration. Use 20 intervals of time. Use any type of line or markers for the graphs. Use a different style for the graph and size. Upload your python file.
#
# ## A car moves with an acceleration of $2 \tfrac{m}{s}$ .The car starts at time t =0 and a position x = 0 and the experiment ends at t = 10s. Find the final position and final velocity from the graphs.

# %%
# You can use this example

x1 = np.linspace(-2,2,11)
z1 = -x1 - 1
z2 = -x1 ** 2 + 4
print (x1)
print (z1)
print (z2)
plt.plot(x1,z1,'r')
plt.plot(x1,z2,'b')
# Out:
# [-2.  -1.6 -1.2 -0.8 -0.4  0.   0.4  0.8  1.2  1.6  2. ]
# [ 1.   0.6  0.2 -0.2 -0.6 -1.  -1.4 -1.8 -2.2 -2.6 -3. ]
# [0.   1.44 2.56 3.36 3.84 4.   3.84 3.36 2.56 1.44 0.  ]
