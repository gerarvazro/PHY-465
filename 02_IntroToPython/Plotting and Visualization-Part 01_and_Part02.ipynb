# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,5,10)
y = 2 * x

# %%
plt.plot(x,y)

# %% [markdown]
# # Second plot on the top of first plot

# %%
plt.plot(x,y)
plt.plot(y,x)

# %% [markdown]
# # Lock the plot by plt.show()

# %%
plt.plot(x,y)
plt.show()
plt.plot(y,x)

# %% [markdown]
# # Change the color of the plot

# %%
y = x ** 2
plt.plot(x,y, 'r') # Different colors are r, y, g, b, other letters would be symbols instead of lines such 
# as ^, v, s, p. You can explore

# %%
# Exercise 01. Graph the functions given on the same plot with different colors. Graph the line y = -x - 1 and 
# the quadratic function y = -x^2 + 4 from -2 to 2. Use a 20 points to make the graphs.

# %% [markdown]
# # Change the size of the plot

# %%
y = x ** 2
plt.figure(figsize = (10,8))  # Here 10 is the width and 8 is the height
plt.plot(x,y, 'r')

# %% [markdown]
# # Increase the width of the line

# %%
y = x ** 2
plt.figure(figsize = (10,8))
plt.plot(x,y, 'r', linewidth = 3)

# %% [markdown]
# # Label x-axis and y-axis

# %%
y = x ** 2
plt.figure(figsize = (10,8))
plt.plot(x,y, 'r', linewidth = 3)
plt.xlabel('Time', fontsize = 15)
plt.ylabel('Amplitude', fontsize = 15)
# Out:
# Text(0, 0.5, 'Amplitude')

# %%
# Exercise 02: Using the same functions given in Exercise 01. Make separated plots with the size of 5 by 5. 
# with a line width of 4 and label the x-axes as time and the y-axes as distance with a fontsize of 12.

# %% [markdown]
# # Making plot more informative by legend and title

# %%
y = x ** 2
plt.figure(figsize = (10,8))
plt.plot(x,y, 'r', linewidth = 3, label = 'y = x ** 2')
plt.xlabel('X', fontsize = 15)
plt.ylabel('Y', fontsize = 15)
plt.legend(fontsize = 20)
plt.title('Visualization of y = x ** 2', fontsize = 25)
plt.show()

# %% [markdown]
# # Setting limits for x-axis and y-axis

# %%
t = np.linspace(0,10,100)
A = 5
f = 50
sine_wave = A * np.sin(2 * np.pi * f * t)
plt.figure(figsize = (16,8))
plt.plot(t,sine_wave,linewidth = 3, label = 'SineWave')
plt.xlabel('Time', fontsize = 15)
plt.ylabel('Amplitude', fontsize = 15)
plt.ylim(-6,6) # setting limit on y-axis
plt.xlim(-1,11) # setting limit on x-axis

plt.legend(fontsize = 10)
plt.title('Visualization of Sine wave', fontsize = 25)
plt.show()

# %%
# Exercise 03: Make two graphs one with a sine and the other with cosine function. Make title and label for the  
# functions. Make the amplitude for both to 3 and frequency 75 and divide an interval of 10s into 150 steps. 
# Make the label for the x-axes as time, and y-axes as amplitude. Set the limits in x from -1 to 11 and in y 
# from -4.5 to 4.5. Make each plot a size (8,4).

# %%
# Exercise 04: Put both graphs on the same plot with the functions in different color.

# %% [markdown]
# # Using xticks and yticks

# %%
t = np.linspace(0,10,100)
A = 5
f = 50
sine_wave = A * np.sin(2 * np.pi * f * t)
plt.figure(figsize = (16,8))
plt.plot(t,sine_wave,linewidth = 3, label = 'SineWave')
plt.xlabel('Time', fontsize = 15)
plt.ylabel('Amplitude', fontsize = 15)
plt.ylim(-5,5) # setting limit on y-axis
plt.xlim(0,10) # setting limit on x-axis
plt.yticks([-5,5])
plt.xticks([0,10])
plt.legend(fontsize = 10)
plt.title('Visualization of Sine wave', fontsize = 25)
plt.show()

# %% [markdown]
# # Removing axes from the plot

# %%
t = np.linspace(0,10,100)
A = 5
f = 50
sine_wave = A * np.sin(2 * np.pi * f * t)
plt.figure(figsize = (16,8))
plt.plot(t,sine_wave,linewidth = 3, label = 'SineWave')
plt.xlabel('Time', fontsize = 15)
plt.ylabel('Amplitude', fontsize = 15)
plt.ylim(-5,5) # setting limit on y-axis
plt.xlim(0,10) # setting limit on x-axis
plt.axis('off')
plt.legend(fontsize = 10)
plt.title('Visualization of Sine wave', fontsize = 25)
plt.show()

# %% [markdown]
# # Making Plot nicer and nicer

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

# %%
t = np.linspace(0,10,100)
A = 5
f = 50
sine_wave = A * np.sin(2 * np.pi * f * t)
style.use('dark_background')
plt.figure(figsize = (16,8))
plt.plot(t,sine_wave,color = 'r',ls = '--', lw = 2, marker = 'o', markersize = 10, markerfacecolor = 'g',markeredgecolor = 'y',label = 'SineWave')
plt.xlabel('Time', fontsize = 15)
plt.ylabel('Amplitude', fontsize = 15)
plt.ylim(-5,5) 
plt.xlim(0,10) 
plt.grid()
plt.legend(fontsize = 10)
plt.title('Visualization of Sine wave', fontsize = 25)
plt.show()

# %% [markdown]
# # Looking for more styles

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
t = np.linspace(0,10,100)
A = 5
f = 50
sine_wave = A * np.sin(2 * np.pi * f * t)
style.use('grayscale')
plt.figure(figsize = (16,8))
plt.plot(t,sine_wave,color = 'r',ls = '--', lw = 2, marker = 'o', markersize = 10, markerfacecolor = 'g',markeredgecolor = 'y',label = 'SineWave')
plt.xlabel('Time', fontsize = 15)
plt.ylabel('Amplitude', fontsize = 15)
plt.ylim(-5,5) 
plt.xlim(0,10) 
plt.grid()
plt.legend(fontsize = 10)
plt.title('Visualization of Sine wave', fontsize = 25)
plt.show()

# %%
# Exercise 05: Make prettier the graph you made in exercise 04. Use a different style and yticks and xticks and markers.
